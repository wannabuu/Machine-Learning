# %% [markdown]
# # **LAB 1 - PART 1**
# Data exploration, cleaning and preprocessing

# %% [markdown]
# ### Import tools

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# ## **1. Data Exploration**
# Read the Data_example.csv files
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - `pd.read_csv()`
#
#
# <details>
# <summary>
# <font size="3" color="green">
# <b>more hints</b>
# </summary>
# </font>
#
# How was the file encoded?🤔
# </details>
# </details>

# %%
### START CODE HERE ###

df = pd.read_csv("Data_example.csv",encoding='latin-1',sep=",")
### END CODE HERE ###

# %% [markdown]
# Visulize the dataframe in cell below.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output
# </font>
# </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
print(df)
### END CODE HERE ###
# Out:
#        X     Y        Z
# 0     19  1927      cat
# 1    NaN  2300      dog
# 2     15   NaN     bird
# 3     16  5959      cat
# 4     16    AB      cat
# 5    NaN  4594      dog
# 6     19  1927      cat
# 7     20  2879  birdËÁÒ
# 8     21   NaN      NaN
# 9      0  4096      cat
# 10     A  6730      cat
# 11    25     0     bird
# 12     0  2792      dog
# 13    33  2575    dog¹¡
# 14  1000  4959     bird
# 15    19  1927      cat
# 16    36  4580      dog
# 17    40  5869      NaN
# 18   NaN  4178      dog
# 19    45   NaN      cat

# %% [markdown]
# View the data frame information
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# -  `.info()`
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       20 non-null     Int64
#  1   Y       20 non-null     float64
#  2   Z       20 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 628.0 bytes
# ```
#
# </details>

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       17 non-null     object
#  1   Y       17 non-null     object
#  2   Z       18 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
# None

# %% [markdown]
# ## **2. Data Cleaning**

# %% [markdown]
# ### Replace
# Use the `replace()` method to remove non-ASCII characters from specific columns in the DataFrame. Then visualize the DataFrame.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Use regular expression.
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
df.replace(r'[^\x00-\x7F]',value='', regex=True,inplace=True)
### END CODE HERE ###
df
# Out:
#        X     Y     Z
# 0     19  1927   cat
# 1    NaN  2300   dog
# 2     15   NaN  bird
# 3     16  5959   cat
# 4     16    AB   cat
# 5    NaN  4594   dog
# 6     19  1927   cat
# 7     20  2879  bird
# 8     21   NaN   NaN
# 9      0  4096   cat
# 10     A  6730   cat
# 11    25     0  bird
# 12     0  2792   dog
# 13    33  2575   dog
# 14  1000  4959  bird
# 15    19  1927   cat
# 16    36  4580   dog
# 17    40  5869   NaN
# 18   NaN  4178   dog
# 19    45   NaN   cat

# %% [markdown]
# ### Convert Data Types
# Converting the data types of specific columns in a pandas DataFrame.
#
# | Column | Data Type |
# | ------ | --------- |
# | X      | int64     |
# | Y      | float64   |
# | Z      | string    |
#
# </br>
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - `pd.to_numeric()` and `.astype()` might be useful here.
# </details>

# %%
### START CODE HERE ###
df['X'] = pd.to_numeric(df['X'], errors='coerce').astype("Int64")
df['Y'] = pd.to_numeric(df['Y'], errors='coerce').astype("float64")
df['Z'] = df['Z'].astype('string')
### END CODE HERE ###

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       16 non-null     Int64
#  1   Y       16 non-null     float64
#  2   Z       18 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 628.0 bytes
#
# ```
#
# </details>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       16 non-null     Int64
#  1   Y       16 non-null     float64
#  2   Z       18 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 628.0 bytes

# %% [markdown]
# ### Drop the duplicates
# Drop the duplicates rows using
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - `.drop_duplicates(inplace=True)`
# </details>

# %%
### START CODE HERE ###

df.drop_duplicates(inplace=True)
df
### END CODE HERE ###
# Out:
#        X       Y     Z
# 0     19  1927.0   cat
# 1   <NA>  2300.0   dog
# 2     15     NaN  bird
# 3     16  5959.0   cat
# 4     16     NaN   cat
# 5   <NA>  4594.0   dog
# 7     20  2879.0  bird
# 8     21     NaN  <NA>
# 9      0  4096.0   cat
# 10  <NA>  6730.0   cat
# 11    25     0.0  bird
# 12     0  2792.0   dog
# 13    33  2575.0   dog
# 14  1000  4959.0  bird
# 16    36  4580.0   dog
# 17    40  5869.0  <NA>
# 18  <NA>  4178.0   dog
# 19    45     NaN   cat

# %% [markdown]
# The `df.describe()` output includes the following statistics for each column:
# - count: Number of non-null values
# - mean: Mean (average) value
# - std: Standard deviation, which measures the amount of variation or dispersion
# - min: Minimum value
# - 25%: First quartile (25th percentile)
# - 50%: Median (50th percentile)
# - 75%: Third quartile (75th percentile)
# - max: Maximum value
#
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# </br>
#
# |       |      X |          Y |
# |-------|--------|------------|
# | count | 14.0   | 14.00000   |
# | mean  | 91.857 | 3817.00000 |
# | std   | 261.717| 1837.61074 |
# | min   | 0.0    | 0.00000    |
# | 25%   | 16.0   | 2629.25000 |
# | 50%   | 20.5   | 4137.00000 |
# | 75%   | 35.25  | 4867.75000 |
# | max   | 1000.0 | 6730.00000 |
#
#
# </details>

# %%
df.describe()
# Out:
#                 X           Y
# count        14.0    14.00000
# mean    91.857143  3817.00000
# std    261.717069  1837.61074
# min           0.0     0.00000
# 25%          16.0  2629.25000
# 50%          20.5  4137.00000
# 75%         35.25  4867.75000
# max        1000.0  6730.00000

# %% [markdown]
# ### Drop NAN

# %% [markdown]
# The `df.dropna()` method will return a new DataFrame with rows that do not contain any missing values. It removes any row where at least one element is missing. By default, this operation is performed on all columns. </br></br>
# In the cell below, you will drop rows that have ***2 NaN values***.

# %%
### START CODE HERE ###
df = df.dropna(thresh=2)
### END CODE HERE ###
df
# Out:
#        X       Y     Z
# 0     19  1927.0   cat
# 1   <NA>  2300.0   dog
# 2     15     NaN  bird
# 3     16  5959.0   cat
# 4     16     NaN   cat
# 5   <NA>  4594.0   dog
# 7     20  2879.0  bird
# 9      0  4096.0   cat
# 10  <NA>  6730.0   cat
# 11    25     0.0  bird
# 12     0  2792.0   dog
# 13    33  2575.0   dog
# 14  1000  4959.0  bird
# 16    36  4580.0   dog
# 17    40  5869.0  <NA>
# 18  <NA>  4178.0   dog
# 19    45     NaN   cat

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       13 non-null     Int64
#  1   Y       14 non-null     float64
#  2   Z       16 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes
#
# ```
#
# </details>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       13 non-null     Int64
#  1   Y       14 non-null     float64
#  2   Z       16 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes

# %% [markdown]
# ### Fill NA
# Before proceeding with filling missing values, it is crucial to comprehend the significance of each numerical column in the dataset. This understanding will guide the appropriate method for handling missing data in a way that aligns with the context and characteristics of each column.

# %% [markdown]
# Replace the NA with specific values or conditions.
#
# | Column | Condition |
# | ------ | --------- |
# | X      | mean or median    |
# | Y      | mean or median    |
# | Z      | previous row    |

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Please explore the statistical values for each column (mean, median, min, max, etc.).
# - `.fillna()`
# </details>

# %%
### START CODE HERE ###
df['X'] = df['X'].fillna(df['X'].median())
df['Y'] = df['Y'].fillna(df['Y'].mean())
df['Z'] = df['Z'].fillna(method='ffill')
### END CODE HERE ###
df
# Out:
# <ipython-input-163-83e398a95d13>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X'] = df['X'].fillna(df['X'].median())
# <ipython-input-163-83e398a95d13>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y'] = df['Y'].fillna(df['Y'].mean())
# <ipython-input-163-83e398a95d13>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Z'] = df['Z'].fillna(method='ffill')
#        X       Y     Z
# 0     19  1927.0   cat
# 1     20  2300.0   dog
# 2     15  3817.0  bird
# 3     16  5959.0   cat
# 4     16  3817.0   cat
# 5     20  4594.0   dog
# 7     20  2879.0  bird
# 9      0  4096.0   cat
# 10    20  6730.0   cat
# 11    25     0.0  bird
# 12     0  2792.0   dog
# 13    33  2575.0   dog
# 14  1000  4959.0  bird
# 16    36  4580.0   dog
# 17    40  5869.0   dog
# 18    20  4178.0   dog
# 19    45  3817.0   cat

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# ```
# Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       17 non-null     Int64
#  1   Y       17 non-null     float64
#  2   Z       17 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes
#
# ```
#
# </details>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       17 non-null     Int64
#  1   Y       17 non-null     float64
#  2   Z       17 non-null     string
# dtypes: Int64(1), float64(1), string(1)
# memory usage: 561.0 bytes

# %% [markdown]
# <font size="3" color="Red">
# <b>Which fill NA method have you selected, and why? </br>Please explain in the cell below.</b>
# </font>

# %%
"""

Type your answer here.

"""
# Out:
# '\n\nType your answer here.\n\n'

# %% [markdown]
# ## **3. Data Transform**
# **NOTE** : This section will demonstrate the difference between Min-Max scaling and Standard scaling before and after removing outliers.

# %% [markdown]
# Show the boxplot of original dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
sns.boxplot(df)


### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# ### Min-Max Scaling
#
# Scaling columns X and Y using Min-Max scaling and placing the results in new columns of `tmpmm_df`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
tmpmm_df = df.copy()
### START CODE HERE ###
tmpmm_df.drop( 'Z', axis='columns', inplace=True)
minmax_scaler = preprocessing.MinMaxScaler()
minmax = minmax_scaler.fit_transform(tmpmm_df)

tmpmm_df['X_maxmin'] =minmax_scaler.fit_transform(df[["X"]])
tmpmm_df['Y_maxmin'] = minmax_scaler.fit_transform(df[["Y"]])

### END CODE HERE ###
tmpmm_df
# Out:
#        X       Y  X_maxmin  Y_maxmin
# 0     19  1927.0     0.019  0.286330
# 1     20  2300.0     0.020  0.341753
# 2     15  3817.0     0.015  0.567162
# 3     16  5959.0     0.016  0.885438
# 4     16  3817.0     0.016  0.567162
# 5     20  4594.0     0.020  0.682615
# 7     20  2879.0     0.020  0.427786
# 9      0  4096.0     0.000  0.608618
# 10    20  6730.0     0.020  1.000000
# 11    25     0.0     0.025  0.000000
# 12     0  2792.0     0.000  0.414859
# 13    33  2575.0     0.033  0.382615
# 14  1000  4959.0     1.000  0.736850
# 16    36  4580.0     0.036  0.680535
# 17    40  5869.0     0.040  0.872065
# 18    20  4178.0     0.020  0.620802
# 19    45  3817.0     0.045  0.567162

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_minmax     | Y_minmax     |
# |---------|--------------|--------------|--------------|--------------|
# | count   | 17.0         | 17.000000    | 17.000000    | 17.000000    |
# | mean    | 79.117647    | 3817.000000  | 0.079118     | 0.567162     |
# | std     | 237.607839   | 1656.399937  | 0.237608     | 0.246122     |
# | min     | 0.0          | 0.000000     | 0.000000     | 0.000000     |
# | 25%     | 16.0         | 2792.000000  | 0.016000     | 0.414859     |
# | 50%     | 20.0         | 3817.000000  | 0.020000     | 0.567162     |
# | 75%     | 33.0         | 4594.000000  | 0.033000     | 0.682615     |
# | max     | 1000.0       | 6730.000000  | 1.000000     | 1.000000     |
#
# </details>

# %%
tmpmm_df.describe()
# Out:
#                 X            Y   X_maxmin   Y_maxmin
# count        17.0    17.000000  17.000000  17.000000
# mean    79.117647  3817.000000   0.079118   0.567162
# std    237.607839  1656.399937   0.237608   0.246122
# min           0.0     0.000000   0.000000   0.000000
# 25%          16.0  2792.000000   0.016000   0.414859
# 50%          20.0  3817.000000   0.020000   0.567162
# 75%          33.0  4594.000000   0.033000   0.682615
# max        1000.0  6730.000000   1.000000   1.000000

# %% [markdown]
# Show the boxplot of Min-Max scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
#
# ![image.png](attachment:image.png)
#
# </details>

# %%
### START CODE HERE ###
sns.boxplot(tmpmm_df[['X','Y']])


### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# #### Remove outliers
# Remove outliers from the DataFrame `tmpmm_df2` based on the boxplot method. The Interquartile Range (IQR) is used to define the range within which data points are considered normal, and points outside this range are treated as potential outliers.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# 1. Calculating Quartiles and IQR:
#
# >- $Q_{1_X}, Q_{3_X}, IQR_X$ : Calculate the first quartile, third quartile, and IQR for column 'X'.
# >- $Q_{1_Y}, Q_{3_Y}, IQR_Y$ : Calculate the first quartile, third quartile, and IQR for column 'Y'.
# 2. Defining Lower and Upper Bounds:
#
# >- lower_bound_X, upper_bound_X: Define the lower and upper bounds for column 'X' using the $1.5 * IQR$ rule.
# >- lower_bound_Y, upper_bound_Y: Define the lower and upper bounds for column 'Y' using the $1.5 * IQR$ rule.
# 3. Creating Outlier Mask:
#
# >- outlier_mask: Create a boolean mask to identify rows containing outliers. Rows where values fall outside the defined bounds for either 'X' or 'Y' are marked as outliers.
# 4. Removing Outliers:
# >- Update `tmpmm_df2` by keeping only the rows where the values are not marked as outliers according to the mask.
# </details>

# %%
tmpmm_df2 = tmpmm_df.copy()
### START CODE HERE ###
Q1_X = tmpmm_df2['X'].quantile(0.25)
Q3_X = tmpmm_df2['X'].quantile(0.75)
IQR_X = Q3_X - Q1_X
Q1_Y = tmpmm_df2['Y'].quantile(0.25)
Q3_Y = tmpmm_df2['Y'].quantile(0.75)
IQR_Y = Q3_Y-Q1_Y

lower_bound_X = Q1_X - (1.5*IQR_X)
upper_bound_X = Q3_X + (1.5*IQR_X)

lower_bound_Y = Q1_Y - (1.5*IQR_Y)
upper_bound_Y = Q3_Y + (1.5*IQR_Y)

outlier_mask = (tmpmm_df2['X'] < lower_bound_X) | (tmpmm_df2['X'] > upper_bound_X) | (tmpmm_df2['Y'] < lower_bound_Y) | (tmpmm_df2['Y'] > upper_bound_Y)
tmpmm_df2 = tmpmm_df2[~outlier_mask]
### END CODE HERE ###
tmpmm_df2
# Out:
#      X       Y  X_maxmin  Y_maxmin
# 0   19  1927.0     0.019  0.286330
# 1   20  2300.0     0.020  0.341753
# 2   15  3817.0     0.015  0.567162
# 3   16  5959.0     0.016  0.885438
# 4   16  3817.0     0.016  0.567162
# 5   20  4594.0     0.020  0.682615
# 7   20  2879.0     0.020  0.427786
# 9    0  4096.0     0.000  0.608618
# 10  20  6730.0     0.020  1.000000
# 12   0  2792.0     0.000  0.414859
# 13  33  2575.0     0.033  0.382615
# 16  36  4580.0     0.036  0.680535
# 17  40  5869.0     0.040  0.872065
# 18  20  4178.0     0.020  0.620802
# 19  45  3817.0     0.045  0.567162

# %% [markdown]
# After removing outliers, scale columns X and Y using Min-Max scaling, and place the results in new columns of `tmpmm_df2`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
### START CODE HERE ###
minmax_scaler = preprocessing.MinMaxScaler()
tmpmm_df2['X_maxmin'] =minmax_scaler.fit_transform(tmpmm_df2[["X"]])
tmpmm_df2['Y_maxmin'] = minmax_scaler.fit_transform(tmpmm_df2[["Y"]])
### END CODE HERE ###
tmpmm_df2
# Out:
#      X       Y  X_maxmin  Y_maxmin
# 0   19  1927.0  0.422222  0.000000
# 1   20  2300.0  0.444444  0.077660
# 2   15  3817.0  0.333333  0.393504
# 3   16  5959.0  0.355556  0.839475
# 4   16  3817.0  0.355556  0.393504
# 5   20  4594.0  0.444444  0.555278
# 7   20  2879.0  0.444444  0.198209
# 9    0  4096.0  0.000000  0.451593
# 10  20  6730.0  0.444444  1.000000
# 12   0  2792.0  0.000000  0.180096
# 13  33  2575.0  0.733333  0.134916
# 16  36  4580.0  0.800000  0.552363
# 17  40  5869.0  0.888889  0.820737
# 18  20  4178.0  0.444444  0.468665
# 19  45  3817.0  1.000000  0.393504

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_minmax     | Y_minmax     |
# |---------|--------------|--------------|--------------|--------------|
# | count   | 15.0         | 15.000000    | 15.000000    | 15.000000    |
# | mean    | 21.333333    | 3995.333333  | 0.474074     | 0.430634     |
# | std     | 12.76528     | 1402.749273  | 0.283673     | 0.292057     |
# | min     | 0.0          | 1927.000000  | 0.000000     | 0.000000     |
# | 25%     | 16.0         | 2835.500000  | 0.355556     | 0.189153     |
# | 50%     | 20.0         | 3817.000000  | 0.444444     | 0.393504     |
# | 75%     | 26.5         | 4587.000000  | 0.588889     | 0.553821     |
# | max     | 45.0         | 6730.000000  | 1.000000     | 1.000000     |
# </details>

# %%
tmpmm_df2.describe()
# Out:
#                X            Y   X_maxmin   Y_maxmin
# count       15.0    15.000000  15.000000  15.000000
# mean   21.333333  3995.333333   0.474074   0.430634
# std     12.76528  1402.749273   0.283673   0.292057
# min          0.0  1927.000000   0.000000   0.000000
# 25%         16.0  2835.500000   0.355556   0.189153
# 50%         20.0  3817.000000   0.444444   0.393504
# 75%         26.5  4587.000000   0.588889   0.553821
# max         45.0  6730.000000   1.000000   1.000000

# %% [markdown]
# Show the removed outliers boxplot of Min-Max scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
#
# ![image.png](attachment:image.png)
# </details>

# %%
### START CODE HERE ###
sns.boxplot(data=tmpmm_df2[['X','Y']])

### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# ### Standardize Scaling
#
# Scaling columns X and Y using Standardize scaling and placing the results in new columns of `tmpstd_df`.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
tmpstd_df = df.copy()
### START CODE HERE ###
tmpstd_df.drop( 'Z', axis='columns', inplace=True)
standardize_scaler = preprocessing.StandardScaler()
# standardize = standardize_scaler.fit_transform(tmpmm_df)

tmpstd_df['X_standardize'] =standardize_scaler.fit_transform(df[["X"]])
tmpstd_df['Y_standardize'] = standardize_scaler.fit_transform(df[["Y"]])

### END CODE HERE ###
tmpstd_df
# Out:
#        X       Y  X_standardize  Y_standardize
# 0     19  1927.0      -0.260799      -1.176146
# 1     20  2300.0      -0.256461      -0.944028
# 2     15  3817.0      -0.278151       0.000000
# 3     16  5959.0      -0.273813       1.332965
# 4     16  3817.0      -0.273813       0.000000
# 5     20  4594.0      -0.256461       0.483527
# 7     20  2879.0      -0.256461      -0.583717
# 9      0  4096.0      -0.343224       0.173621
# 10    20  6730.0      -0.256461       1.812758
# 11    25     0.0      -0.234770      -2.375316
# 12     0  2792.0      -0.343224      -0.637857
# 13    33  2575.0      -0.200065      -0.772896
# 14  1000  4959.0       3.994918       0.710666
# 16    36  4580.0      -0.187050       0.474814
# 17    40  5869.0      -0.169698       1.276958
# 18    20  4178.0      -0.256461       0.224650
# 19    45  3817.0      -0.148007       0.000000

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_standardize   | Y_standardize  |
# |---------|--------------|--------------|-----------------|-----------------|
# | count   | 17.0         | 17.000000    | 1.700000e+01    | 17.000000      |
# | mean    | 79.117647    | 3817.000000  | -2.612289e-17   | 0.000000       |
# | std     | 237.607839   | 1656.399937  | 1.030776e+00    | 1.030776       |
# | min     | 0.0          | 0.000000     | -3.432235e-01   | -2.375316      |
# | 25%     | 16.0         | 2792.000000  | -2.738133e-01   | -0.637857      |
# | 50%     | 20.0         | 3817.000000  | -2.564607e-01   | 0.000000       |
# | 75%     | 33.0         | 4594.000000  | -2.000649e-01   | 0.483527       |
# | max     | 1000.0       | 6730.000000  | 3.994918e+00    | 1.812758       |
#
# </details>

# %%
tmpstd_df.describe()
# Out:
#                 X            Y  X_standardize  Y_standardize
# count        17.0    17.000000   1.700000e+01      17.000000
# mean    79.117647  3817.000000  -2.612289e-17       0.000000
# std    237.607839  1656.399937   1.030776e+00       1.030776
# min           0.0     0.000000  -3.432235e-01      -2.375316
# 25%          16.0  2792.000000  -2.738133e-01      -0.637857
# 50%          20.0  3817.000000  -2.564607e-01       0.000000
# 75%          33.0  4594.000000  -2.000649e-01       0.483527
# max        1000.0  6730.000000   3.994918e+00       1.812758

# %% [markdown]
# Show the removed outliers boxplot of Min-Max scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# ![image.png](attachment:image.png)
# </details>

# %%
### START CODE HERE ###
sns.boxplot(tmpstd_df[['X','Y']])

### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# #### Remove outliers
# from the DataFrame `tmpstd_df2` based on the boxplot method. The Interquartile Range (IQR) is used to define the range within which data points are considered normal, and points outside this range are treated as potential outliers.
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Similar with the previous.
# </details>

# %%
tmpstd_df2 = tmpstd_df.copy()
### START CODE HERE ###
Q1_X = tmpstd_df2['X'].quantile(0.25)
Q3_X = tmpstd_df2['X'].quantile(0.75)
IQR_X = Q3_X - Q1_X
Q1_Y = tmpstd_df2['Y'].quantile(0.25)
Q3_Y = tmpstd_df2['Y'].quantile(0.75)
IQR_Y = Q3_Y-Q1_Y

lower_bound_X = Q1_X - (1.5*IQR_X)
upper_bound_X = Q3_X + (1.5*IQR_X)

lower_bound_Y = Q1_Y - (1.5*IQR_Y)
upper_bound_Y = Q3_Y + (1.5*IQR_Y)

outlier_mask = (tmpstd_df2['X'] < lower_bound_X) | (tmpstd_df2['X'] > upper_bound_X) | (tmpstd_df2['Y'] < lower_bound_Y) | (tmpstd_df2['Y'] > upper_bound_Y)
tmpstd_df2 = tmpstd_df2[~outlier_mask]
### END CODE HERE ###
tmpstd_df2
# Out:
#      X       Y  X_standardize  Y_standardize
# 0   19  1927.0      -0.260799      -1.176146
# 1   20  2300.0      -0.256461      -0.944028
# 2   15  3817.0      -0.278151       0.000000
# 3   16  5959.0      -0.273813       1.332965
# 4   16  3817.0      -0.273813       0.000000
# 5   20  4594.0      -0.256461       0.483527
# 7   20  2879.0      -0.256461      -0.583717
# 9    0  4096.0      -0.343224       0.173621
# 10  20  6730.0      -0.256461       1.812758
# 12   0  2792.0      -0.343224      -0.637857
# 13  33  2575.0      -0.200065      -0.772896
# 16  36  4580.0      -0.187050       0.474814
# 17  40  5869.0      -0.169698       1.276958
# 18  20  4178.0      -0.256461       0.224650
# 19  45  3817.0      -0.148007       0.000000

# %% [markdown]
# After removing outliers, scale columns X and Y using Standardize scaling, and place the results in new columns of `tmpstd_df2`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %%
### STAET CODE HERE ###
standardize_scaler = preprocessing.StandardScaler()
tmpstd_df2['X_standardize'] =standardize_scaler.fit_transform(tmpstd_df2[["X"]])
tmpstd_df2['Y_standardize'] = standardize_scaler.fit_transform(tmpstd_df2[["Y"]])

### END CODE HERE ###
tmpstd_df2
# Out:
#      X       Y  X_standardize  Y_standardize
# 0   19  1927.0      -0.189203      -1.526237
# 1   20  2300.0      -0.108116      -1.250998
# 2   15  3817.0      -0.513551      -0.131593
# 3   16  5959.0      -0.432464       1.449003
# 4   16  3817.0      -0.432464      -0.131593
# 5   20  4594.0      -0.108116       0.441760
# 7   20  2879.0      -0.108116      -0.823750
# 9    0  4096.0      -1.729856       0.074283
# 10  20  6730.0      -0.108116       2.017929
# 12   0  2792.0      -1.729856      -0.887948
# 13  33  2575.0       0.946015      -1.048074
# 16  36  4580.0       1.189276       0.431430
# 17  40  5869.0       1.513624       1.382592
# 18  20  4178.0      -0.108116       0.134791
# 19  45  3817.0       1.919059      -0.131593

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |         | X            | Y            | X_standardize   | Y_standardize  |
# |---------|--------------|--------------|-----------------|-----------------|
# | count   | 15.0         | 15.000000    | 1.500000e+01    | 1.500000e+01    |
# | mean    | 21.333333    | 3995.333333  | 1.332268e-16   | -8.326673e-17  |
# | std     | 12.76528     | 1402.749273  | 1.035098e+00   | 1.035098e+00   |
# | min     | 0.0          | 1927.000000  | -1.729856e+00  | -1.526237e+00  |
# | 25%     | 16.0         | 2835.500000  | -4.324640e-01  | -8.558490e-01  |
# | 50%     | 20.0         | 3817.000000  | -1.081160e-01  | -1.315934e-01  |
# | 75%     | 26.5         | 4587.000000  | 4.189495e-01   | 4.365949e-01   |
# | max     | 45.0         | 6730.000000  | 1.919059e+00   | 2.017929e+00   |
#
# </details>

# %%
tmpstd_df2.describe()
# Out:
#                X            Y  X_standardize  Y_standardize
# count       15.0    15.000000   1.500000e+01   1.500000e+01
# mean   21.333333  3995.333333   1.332268e-16  -8.326673e-17
# std     12.76528  1402.749273   1.035098e+00   1.035098e+00
# min          0.0  1927.000000  -1.729856e+00  -1.526237e+00
# 25%         16.0  2835.500000  -4.324640e-01  -8.558490e-01
# 50%         20.0  3817.000000  -1.081160e-01  -1.315934e-01
# 75%         26.5  4587.000000   4.189495e-01   4.365949e-01
# max         45.0  6730.000000   1.919059e+00   2.017929e+00

# %% [markdown]
# Show the removed outliers boxplot of Standardize scaled dataframe.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# ![image.png](attachment:image.png)
# </details>

# %%
### START CODE HERE ###
sns.boxplot(data=tmpstd_df2[['X','Y']])

### END CODE HERE ###
# Out:
# <Axes: >

# %% [markdown]
# ## **4. Data Category Label**

# %% [markdown]
# **NOTE** : Please select one of the Scaling type from the previous section.

# %%
### START CODE HERE ###
temp_df = df.copy()
standardize_scaler = preprocessing.StandardScaler()
minmax_scaler = preprocessing.MinMaxScaler()
df['X'] =minmax_scaler.fit_transform(temp_df[["X"]])
df['Y'] = minmax_scaler.fit_transform(temp_df[["Y"]])

Q1_X = df['X'].quantile(0.25)
Q3_X = df['X'].quantile(0.75)
IQR_X = Q3_X - Q1_X
Q1_Y = df['Y'].quantile(0.25)
Q3_Y = df['Y'].quantile(0.75)
IQR_Y = Q3_Y-Q1_Y

lower_bound_X = Q1_X - (1.5*IQR_X)
upper_bound_X = Q3_X + (1.5*IQR_X)

lower_bound_Y = Q1_Y - (1.5*IQR_Y)
upper_bound_Y = Q3_Y + (1.5*IQR_Y)

outlier_mask = (df['X'] < lower_bound_X) | (df['X'] > upper_bound_X) | (df['Y'] < lower_bound_Y) | (df['Y'] > upper_bound_Y)

df = df[~outlier_mask]

### END CODE HERE ###
df
# Out:
# <ipython-input-187-d0c92f660abd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X'] =minmax_scaler.fit_transform(temp_df[["X"]])
# <ipython-input-187-d0c92f660abd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y'] = minmax_scaler.fit_transform(temp_df[["Y"]])
#            X         Y     Z
# 0   0.422222  0.000000   cat
# 1   0.444444  0.077660   dog
# 2   0.333333  0.393504  bird
# 3   0.355556  0.839475   cat
# 4   0.355556  0.393504   cat
# 5   0.444444  0.555278   dog
# 7   0.444444  0.198209  bird
# 10  0.444444  1.000000   cat
# 13  0.733333  0.134916   dog
# 16  0.800000  0.552363   dog
# 17  0.888889  0.820737   dog
# 18  0.444444  0.468665   dog

# %%
sns.boxplot(data=df[['X', 'Y']])
plt.show()

# %% [markdown]
# Reset DataFrame index.
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |   | X        | Y        | Z    |
# |---|----------|----------|------|
# | 0 | 0.422222 | 0.000000 | cat  |
# | 1 | 0.444444 | 0.077660 | dog  |
# | 2 | 0.333333 | 0.393504 | bird |
# | 3 | 0.355556 | 0.839475 | cat  |
# | 4 | 0.355556 | 0.393504 | cat  |
#
#
# </details>

# %%
### START CODE HERE ###
df.reset_index(drop=True,inplace=True)
### END CODE HERE ###
df.head()
# Out:
#           X         Y     Z
# 0  0.422222  0.000000   cat
# 1  0.444444  0.077660   dog
# 2  0.333333  0.393504  bird
# 3  0.355556  0.839475   cat
# 4  0.355556  0.393504   cat

# %% [markdown]
# #### Label Encoding
# Label Encoding `Z` column, and place the results in new columns of `df`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |   | X        | Y        | Z    | Z_labelEn |
# |---|----------|----------|------|-----------|
# | 0 | 0.422222 | 0.000000 | cat  | 1         |
# | 1 | 0.444444 | 0.077660 | dog  | 2         |
# | 2 | 0.333333 | 0.393504 | bird | 0         |
# | 3 | 0.355556 | 0.839475 | cat  | 1         |
# | 4 | 0.355556 | 0.393504 | cat  | 1         |
#
#
# </details>

# %%
### START CODE HERE ###
label_En = None
df['Z_labelEn'] =preprocessing.LabelEncoder().fit_transform(df["Z"])
### END CODE HERE ###
df.head()
# Out:
# <ipython-input-191-d6980eddc410>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Z_labelEn'] =preprocessing.LabelEncoder().fit_transform(df["Z"])
#           X         Y     Z  Z_labelEn
# 0  0.422222  0.000000   cat          1
# 1  0.444444  0.077660   dog          2
# 2  0.333333  0.393504  bird          0
# 3  0.355556  0.839475   cat          1
# 4  0.355556  0.393504   cat          1

# %% [markdown]
# #### One Hot Encoding
# One Hot Encoding `Z` column, and place the results in new columns of `df`.
#
# <details>
#
# <summary>
# <font size="3" color="green">
# <b>Hints</b>
# </font>
# </summary>
#
# - Scikitlearn's `preprocessing` migth be useful here.</br>
# https://scikit-learn.org/stable/modules/preprocessing.html
# </details>

# %% [markdown]
# <details>
#
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical, depending on your `.fillna()` method.</br>
# </br>
#
# |   | X        | Y        | Z    | Z_labelEn | Z_bird | Z_cat | Z_dog |
# |---|----------|----------|------|-----------|--------|-------|-------|
# | 0 | 0.422222 | 0.000000 | cat  | 1         | 0.0    | 1.0   | 0.0   |
# | 1 | 0.444444 | 0.077660 | dog  | 2         | 0.0    | 0.0   | 1.0   |
# | 2 | 0.333333 | 0.393504 | bird | 0         | 1.0    | 0.0   | 0.0   |
# | 3 | 0.355556 | 0.839475 | cat  | 1         | 0.0    | 1.0   | 0.0   |
# | 4 | 0.355556 | 0.393504 | cat  | 1         | 0.0    | 1.0   | 0.0   |
#
# </details>

# %%
### START CODE HERE ###
array = preprocessing.OneHotEncoder().fit_transform(df[["Z"]]).toarray()
oneHot_En = np.ndarray.transpose(array)

df['Z_bird'] = pd.Series(oneHot_En[0])
df['Z_cat'] = pd.Series(oneHot_En[1])
df['Z_dog'] = pd.Series(oneHot_En[2])

### END CODE HERE ###
df.head()
# Out:
# <ipython-input-193-cedb0b6dca76>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Z_bird'] = pd.Series(oneHot_En[0])
# <ipython-input-193-cedb0b6dca76>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Z_cat'] = pd.Series(oneHot_En[1])
# <ipython-input-193-cedb0b6dca76>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Z_dog'] = pd.Series(oneHot_En[2])
#           X         Y     Z  Z_labelEn  Z_bird  Z_cat  Z_dog
# 0  0.422222  0.000000   cat          1     0.0    1.0    0.0
# 1  0.444444  0.077660   dog          2     0.0    0.0    1.0
# 2  0.333333  0.393504  bird          0     1.0    0.0    0.0
# 3  0.355556  0.839475   cat          1     0.0    1.0    0.0
# 4  0.355556  0.393504   cat          1     0.0    1.0    0.0

# %% [markdown]
# Visualize the final DataFrame.

# %%
df
# Out:
#            X         Y     Z  Z_labelEn  Z_bird  Z_cat  Z_dog
# 0   0.422222  0.000000   cat          1     0.0    1.0    0.0
# 1   0.444444  0.077660   dog          2     0.0    0.0    1.0
# 2   0.333333  0.393504  bird          0     1.0    0.0    0.0
# 3   0.355556  0.839475   cat          1     0.0    1.0    0.0
# 4   0.355556  0.393504   cat          1     0.0    1.0    0.0
# 5   0.444444  0.555278   dog          2     0.0    0.0    1.0
# 6   0.444444  0.198209  bird          0     1.0    0.0    0.0
# 7   0.444444  1.000000   cat          1     0.0    1.0    0.0
# 8   0.733333  0.134916   dog          2     0.0    0.0    1.0
# 9   0.800000  0.552363   dog          2     0.0    0.0    1.0
# 10  0.888889  0.820737   dog          2     0.0    0.0    1.0
# 11  0.444444  0.468665   dog          2     0.0    0.0    1.0
